# %% [markdown]
# <a href="https://colab.research.google.com/github/Pbrath2025/sbu-minnesota-healthinsurance-allpayer/blob/main/%20MN_APCD_rxdetail2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency

# %%
## Configure pandas to display non-exponential numbers
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# Load the dataset (modify the filename if needed)
file_path = 'https://raw.githubusercontent.com/hantswilliams/sbu-minnesota-healthinsurance-allpayer/refs/heads/main/data/processed/rxdetail2020.csv'
df = pd.read_csv(file_path)

# %%
### 1. Understanding Diagnosis Code Distribution ###
# Get the top 10 most common principal diagnosis codes
top_10_diagnoses = df['propname'].value_counts().nlargest(10)

# Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_diagnoses.index, y=top_10_diagnoses.values, palette="viridis")
plt.xlabel("Prescribed Drugs")
plt.ylabel("Count")
plt.title("Top 10 Most Prescribed Drugs")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-4-517c76da4b5d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_diagnoses.index, y=top_10_diagnoses.values, palette="viridis")

# %%
### 2. Diagnosis vs. Total Paid Amount ###
# Group by diagnosis code and calculate the mean total paid amount
diagnosis_paid_mean = df.groupby('propname')['total_cost'].mean().nlargest(10)
print("Mean total cost per prescription:")
print(diagnosis_paid_mean)

# Boxplot for top 5 diagnoses
top_10_diagnoses = diagnosis_paid_mean.index
df_top_10 = df[df['propname'].isin(top_10_diagnoses)]

plt.figure(figsize=(12, 6))
sns.boxplot(x="propname", y="total_cost", data=df_top_10, hue="propname", palette="coolwarm", legend=False)
plt.xlabel("Drug Name")
plt.ylabel("Top 5 most expensive drugs")
plt.title("Presciption Drugs")
plt.xticks(rotation=45)
plt.show()
# Out:
# Mean total cost per prescription:
# propname
# HUMIRA PEN                     47551921.84
# NOVOLOG FLEXPEN                31117365.44
# VICTOZA                        30677447.01
# ENBREL SURECLICK               28483519.20
# ELIQUIS                        24032759.97
# TRIKAFTA                       20377456.88
# LANTUS SOLOSTAR                18882363.25
# BIKTARVY                       18694794.41
# COSENTYX SENSOREADY (300 MG)   17044682.72
# STELARA                        13688679.71
# Name: total_cost, dtype: float64

# %%
### 3. Diagnoses by Age Group ###
# Create a contingency table
contingency_table = pd.crosstab(df['ther_class'], df['total_cost'])

# Identify top 3 diagnoses for each age group
top_3_by_age = df.groupby('ther_class')['total_cost'].value_counts().groupby(level=0).head(3)
print("Top 3 theraputic class with highest mean total cost:")
print(top_3_by_age)

# Chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-square Test Result: χ²={chi2:.2f}, p-value={p:.4f}")
if p < 0.05:
    print("Significant difference in cost distrubution across therauptic class.")
else:
    print("No significant difference in cost distribution across theraputic class.")
# Out:
# Top 3 theraputic class with highest mean total cost:
# ther_class                        total_cost
# Analgesics and Anesthetics        8.78          1
#                                   12.41         1
#                                   12.70         1
# Anti-Infective Agents             28.80         1
#                                   36.72         1
#                                   59.67         1
# Antineoplastic Agents             353.36        1
#                                   388.51        1
#                                   608.44        1
# Biologicals                       345.45        1
#                                   549.63        1
#                                   574.47        1
# Cardiovascular Agents             682.56        2
#                                   1998.70       2
#                                   2240.26       2
# Central Nervous System Drugs      869.24        2
#                                   35.69         1
#                                   57.25         1
# Endocrine and Metabolic Drugs     2939.32       2
#                                   54.13         1
#                                   54.89         1
# Gastrointestinal Products         165.57        2
#                                   215.34        2
#                                   432.25        2
# Genitourinary Products            62.10         1
#                                   71.37         1
#                                   72.40         1
# Hematological Agents              737.98        2
#                                   13.24         1
#                                   13.83         1
# Misc Psychotherapeutic/Neurolog   116.82        1
#                                   220.15        1
#                                   238.91        1
# Miscellaneous Products            12.57         1
#                                   18.93         1
#                                   22.43         1
# Neuromuscular Drugs               269.21        2
#                                   19.58         1
#                                   52.98         1
# Nutritional Products              98.54         2
#                                   167.75        2
#                                   499.44        2
# Respiratory Agents                22.50         1
#                                   24.26         1
#                                   26.00         1
# Stimulants/Anti-Obesity/Anorexia  185.20        1
#                                   188.42        1
#                                   195.59        1
# Topical Products                  160.69        2
#                                   23.33         1
#                                   23.59         1
# Name: count, dtype: int64
#
# Chi-square Test Result: χ²=497098.92, p-value=0.3942
# No significant difference in cost distribution across theraputic class.

# %%
### 4. Insurer vs. Member Payment Differences ###
# Group by diagnosis code and calculate means
payment_means = df.groupby('propname')[['insurer_paid_mean', 'member_paid_mean']].mean()
print("Mean Payment Differences by Diagnosis:")
print(payment_means)

# Create a delta between insurer_paid_amt_mean and member_paid_amt_mean
payment_means['delta'] = payment_means['insurer_paid_mean'] - payment_means['member_paid_mean']
print("\nMean Payment Differences with Delta:")
print(payment_means)

# Top diagnoses with highest member out-of-pocket costs
top_member_paid = payment_means['member_paid_mean'].nlargest(5)
print("\nTop 5 drugs with the highest member out-of-pocket costs :")
print(top_member_paid)

# Top diagnoses with highest delta between insurer and member
top_delta = payment_means['delta'].nlargest(5)
print("\nTop 5 Diagnoses with Highest Delta Between Insurer and Member:")
print(top_delta)

# Scatter plot: Insurer Paid vs. Member Paid
plt.figure(figsize=(10, 6))
sns.scatterplot(x='insurer_paid_mean', y='member_paid_mean', data=payment_means, alpha=0.7)
plt.xlabel("Insurer Paid Mean")
plt.ylabel("Member Paid Mean")
plt.title("Insurer vs. Member Payment Differences")
plt.show()
# Out:
# Mean Payment Differences by Diagnosis:
#                                 insurer_paid_mean  member_paid_mean
# propname
# 10 SERIES BP MONITOR/UPPER ARM              48.28              0.20
# 12 HOUR DECONGESTANT                        11.99              1.09
# 12 HOUR NASAL DECONGESTANT                   1.68              0.81
# 24HR ALLERGY RELIEF                          6.82              2.50
# 3 DAY VAGINAL                                8.52              1.19
# ...                                           ...               ...
# ZUMANDIMINE                                 45.50              1.62
# ZYLET                                      224.25             82.19
# ZYPREXA                                   1460.72             21.55
# ZYRTEC-D ALLERGY & CONGESTION               22.60             14.20
# ZYTIGA                                    9522.91            385.23
#
# [3395 rows x 2 columns]
#
# Mean Payment Differences with Delta:
#                                 insurer_paid_mean  member_paid_mean   delta
# propname
# 10 SERIES BP MONITOR/UPPER ARM              48.28              0.20   48.08
# 12 HOUR DECONGESTANT                        11.99              1.09   10.90
# 12 HOUR NASAL DECONGESTANT                   1.68              0.81    0.87
# 24HR ALLERGY RELIEF                          6.82              2.50    4.32
# 3 DAY VAGINAL                                8.52              1.19    7.33
# ...                                           ...               ...     ...
# ZUMANDIMINE                                 45.50              1.62   43.88
# ZYLET                                      224.25             82.19  142.07
# ZYPREXA                                   1460.72             21.55 1439.17
# ZYRTEC-D ALLERGY & CONGESTION               22.60             14.20    8.40
# ZYTIGA                                    9522.91            385.23 9137.67
#
# [3395 rows x 3 columns]
#
# Top 5 drugs with the highest member out-of-pocket costs :
# propname
# FIRAZYR                       2231.31
# GONAL-F                       1801.04
# XPOVIO (80 MG TWICE WEEKLY)   1610.20
# XOSPATA                       1470.03
# ENTYVIO                       1380.25
# Name: member_paid_mean, dtype: float64
#
# Top 5 Diagnoses with Highest Delta Between Insurer and Member:
# propname
# MAVENCLAD (7 TABS)   65194.92
# ICATIBANT ACETATE    40848.85
# ADVATE               33628.16
# HARVONI              29873.18
# OXERVATE             28412.79
# Name: delta, dtype: float64
